# %%
import torch
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array

# %%
# Load pretrained YOLOv5 model from Ultralytics (replace with your own model if needed)
yolo_model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)

# Load your CNN classification model trained on 12 classes
cnn_model = load_model('C:/Users/Angelina/Desktop/Waste-Classification/models/densenet121_waste_classifier.keras')
# Out:
# C:\Users\Angelina\Desktop\Waste-Classification\venv\Lib\site-packages\torch\hub.py:335: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\Angelina/.cache\torch\hub\master.zip
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Load pretrained YOLOv5 model from Ultralytics (replace with your own model if needed)
# ----> 2 yolo_model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
#       4 # Load your CNN classification model trained on 12 classes
#       5 cnn_model = load_model('C:/Users/Angelina/Desktop/Waste-Classification/models/densenet121_waste_classifier.keras')
#
# File ~\Desktop\Waste-Classification\venv\Lib\site-packages\torch\hub.py:652, in load(repo_or_dir, model, source, trust_repo, force_reload, verbose, skip_validation, *args, **kwargs)
#     642 if source == "github":
#     643     repo_or_dir = _get_cache_or_reload(
#     644         repo_or_dir,
#     645         force_reload,
#    (...)    649         skip_validation=skip_validation,
#     650     )
# --> 652 model = _load_local(repo_or_dir, model, *args, **kwargs)
#     653 return model
#
# File ~\Desktop\Waste-Classification\venv\Lib\site-packages\torch\hub.py:682, in _load_local(hubconf_dir, model, *args, **kwargs)
#     680 with _add_to_sys_path(hubconf_dir):
#     681     hubconf_path = os.path.join(hubconf_dir, MODULE_HUBCONF)
# --> 682     hub_module = _import_module(MODULE_HUBCONF, hubconf_path)
#     684     entry = _load_entry_from_hubconf(hub_module, model)
#     685     model = entry(*args, **kwargs)
#
# File ~\Desktop\Waste-Classification\venv\Lib\site-packages\torch\hub.py:115, in _import_module(name, path)
#     113 module = importlib.util.module_from_spec(spec)
#     114 assert isinstance(spec.loader, Loader)
# --> 115 spec.loader.exec_module(module)
#     116 return module
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/.cache\torch\hub\ultralytics_yolov5_master\hubconf.py:13
#       1 # Ultralytics 🚀 AGPL-3.0 License - https://ultralytics.com/license
#       2 """
#       3 PyTorch Hub models https://pytorch.org/hub/ultralytics_yolov5.
#       4
#    (...)     10     model = torch.hub.load('.', 'custom', 'yolov5s.pt', source='local')  # local repo
#      11 """
# ---> 13 from ultralytics.utils.patches import torch_load
#      16 def _create(name, pretrained=True, channels=3, classes=80, autoshape=True, verbose=True, device=None):
#      17     """Creates or loads a YOLOv5 model, with options for pretrained weights and model customization.
#      18
#      19     Args:
#    (...)     51         [YOLOv5 PyTorch Hub Documentation](https://docs.ultralytics.com/yolov5/tutorials/pytorch_hub_model_loading/).
#      52     """
#
# ModuleNotFoundError: No module named 'ultralytics'

# %%
# Hardcoded class names for your CNN classifier
cnn_class_names = ['class1', 'class2', 'class3', 'class4', 'class5', 'class6', 'class7', 'class8', 'class9', 'class10', 'class11', 'class12']

def preprocess_crop(crop_img):
    """Preprocess the cropped image for CNN classification"""
    crop_img = cv2.resize(crop_img, (224, 224))  # Change size according to your CNN input
    crop_img = crop_img.astype("float") / 255.0
    crop_img = img_to_array(crop_img)
    crop_img = np.expand_dims(crop_img, axis=0)
    return crop_img

def detect_and_classify(image_path):
    image = cv2.imread(image_path)
    rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Run YOLO detection
    results = yolo_model(rgb_image)

    # Get detections: xyxy coordinates, confidence, and class predictions from YOLO
    detections = results.xyxy[0].numpy()

    for *box, conf, cls in detections:
        xmin, ymin, xmax, ymax = map(int, box)

        # Crop detected object
        crop = image[ymin:ymax, xmin:xmax]

        # Preprocess crop for CNN and predict
        processed_crop = preprocess_crop(crop)
        preds = cnn_model.predict(processed_crop)
        pred_index = np.argmax(preds[0])
        label = cnn_class_names[pred_index]
        confidence = preds[0][pred_index]

        # Draw bounding box and label on original image
        cv2.rectangle(image, (xmin, ymin), (xmax, ymax), (0, 255, 0), 2)
        text = f"{label}: {confidence*100:.1f}%"
        cv2.putText(image, text, (xmin, ymin - 10), cv2.FONT_HERSHEY_SIMPLEX,
                    0.5, (0, 255, 0), 2)

    # Display the image with bounding boxes and labels
    cv2.imshow("Detection + Classification", image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# Usage example
detect_and_classify('path/to/your/image.jpg')
